# %% [markdown]
# # Real Estate KPI Dashboard — Storyboard
# Load sample data and compute KPIs for quick visuals.

# %%
import pandas as pd
from src.kpi_metrics import rent_roll_health, arrears_aging, lease_expiries
tenants = pd.read_csv('../data/sample_tenants.csv')
ledger = pd.read_csv('../data/sample_ledger.csv')
leases = pd.read_csv('../data/sample_leases.csv')
rent_roll_health(tenants).head()
